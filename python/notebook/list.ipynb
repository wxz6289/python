# %% [markdown]
# # 列表
# ## 列表推导式
# 快速构建序列

# %%
symbols = "abc"
codes = []
for symbol in symbols:
  codes.append(ord(symbol))

print(codes)

codes2 = [ord(sym) for sym in symbols ]
print(codes2)
# Out:
# [97, 98, 99]
# [97, 98, 99]

# %% [markdown]
# ## 生成器表达式
