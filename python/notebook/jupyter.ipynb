# %%
# %load_ext autoreload 启用重载机制
# %autoreload 2 每个单元格都重载
# %aimport mod 导入的模块都会被重新加载一次

# %%
x = 2
print(x)
# Out:
# 2

# %% [markdown]
# Line魔法指令
# %alias 指令别名

# %%
# %lsmagic # 列出所有魔法指令
# %quickref # 输出所有魔法指令的简单帮助文档
# %autoreload? # 查看某个魔法指令的文档
# %alias
# %conda?
# Out:
# Docstring:
# Run the conda package manager within the current kernel.
#
# Usage:
#   %conda install [pkgs]
# File:      ~/miniconda3/lib/python3.12/site-packages/IPython/core/magics/packaging.py
